# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

# %matplotlib inline

# %%
csv_path = Path('whale_returns.csv')
whale_returns = pd.read_csv(csv_path)
whale_returns
# Out:
#             Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 0     2015-03-02                        NaN                 NaN
# 1     2015-03-03                  -0.001266           -0.004981
# 2     2015-03-04                   0.002230            0.003241
# 3     2015-03-05                   0.004016            0.004076
# 4     2015-03-06                  -0.007905           -0.003574
# ...          ...                        ...                 ...
# 1055  2019-04-25                  -0.000285           -0.001291
# 1056  2019-04-26                   0.008149            0.009162
# 1057  2019-04-29                   0.001254            0.002719
# 1058  2019-04-30                  -0.001295           -0.002211
# 1059  2019-05-01                  -0.005847           -0.001341
#
#       TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 0                             NaN                     NaN
# 1                       -0.000496               -0.006569
# ...

# %%
# Count nulls
whale_returns.isnull().mean() * 100
whale_returns.isnull().sum()
# Out:
# Date                           0
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_returns = whale_returns.dropna()

# %%
# Count nulls
whale_returns.isnull().mean() * 100
whale_returns.isnull().sum()
# Out:
# Date                           0
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %%
whale_returns = whale_returns.sort_values(by=['Date'], ascending=True)
whale_returns
# Out:
#             Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 1     2015-03-03                  -0.001266           -0.004981
# 2     2015-03-04                   0.002230            0.003241
# 3     2015-03-05                   0.004016            0.004076
# 4     2015-03-06                  -0.007905           -0.003574
# 5     2015-03-09                   0.000582            0.004225
# ...          ...                        ...                 ...
# 1055  2019-04-25                  -0.000285           -0.001291
# 1056  2019-04-26                   0.008149            0.009162
# 1057  2019-04-29                   0.001254            0.002719
# 1058  2019-04-30                  -0.001295           -0.002211
# 1059  2019-05-01                  -0.005847           -0.001341
#
#       TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 1                       -0.000496               -0.006569
# 2                       -0.002534                0.004213
# ...

# %%
whale_returns['Date'] = whale_returns['Date'].astype("datetime64")

# %%
whale_returns.set_index('Date')
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# ...

# %%
whale_returns.tail(15)
# Out:
#            Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 1045 2019-04-10                   0.009808            0.008366
# 1046 2019-04-11                   0.003406           -0.003959
# 1047 2019-04-12                   0.005663           -0.001165
# 1048 2019-04-15                  -0.001422           -0.001156
# 1049 2019-04-16                   0.002699            0.000388
# 1050 2019-04-17                  -0.002897           -0.006467
# 1051 2019-04-18                   0.001448            0.001222
# 1052 2019-04-22                  -0.002586           -0.007333
# 1053 2019-04-23                   0.007167            0.003485
# 1054 2019-04-24                   0.002284            0.001009
# 1055 2019-04-25                  -0.000285           -0.001291
# 1056 2019-04-26                   0.008149            0.009162
# 1057 2019-04-29                   0.001254            0.002719
# 1058 2019-04-30                  -0.001295           -0.002211
# ...

# %%
whale_returns.tail()
# Out:
#            Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 1049 2019-04-16                   0.002699            0.000388
# 1050 2019-04-17                  -0.002897           -0.006467
# 1051 2019-04-18                   0.001448            0.001222
# 1052 2019-04-22                  -0.002586           -0.007333
# 1059 2019-05-01                  -0.005847           -0.001341
#
#       TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 1049                    -0.000831                0.000837
# 1050                    -0.004409                0.003222
# 1051                     0.000582                0.001916
# 1052                    -0.003640               -0.001088
# 1059                    -0.007936               -0.007833

# %%
whale_returns = whale_returns.drop(labels=1059, axis=0)

# %%
whale_returns.tail()
# Out:
#            Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 1048 2019-04-15                  -0.001422           -0.001156
# 1049 2019-04-16                   0.002699            0.000388
# 1050 2019-04-17                  -0.002897           -0.006467
# 1051 2019-04-18                   0.001448            0.001222
# 1052 2019-04-22                  -0.002586           -0.007333
#
#       TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 1048                     0.000398               -0.010492
# 1049                    -0.000831                0.000837
# 1050                    -0.004409                0.003222
# 1051                     0.000582                0.001916
# 1052                    -0.003640               -0.001088

# %%
whale_returns = whale_returns.drop(labels=range(1004, 1059), axis=0)

# %%
whale_returns.tail(50)
# Out:
#            Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 1004 2019-02-11                  -0.000991            0.003465
# 1005 2019-02-12                   0.000000            0.000000
# 1006 2019-02-13                   0.000000            0.000000
# 1007 2019-02-14                   0.002795            0.001987
# 1008 2019-02-15                   0.006410            0.007684
# 1009 2019-02-19                   0.003437            0.000896
# 1010 2019-02-20                   0.003650           -0.001690
# 1011 2019-02-21                  -0.001401           -0.004180
# 1012 2019-02-22                   0.001011            0.004447
# 1013 2019-02-25                  -0.002242           -0.003639
# 1014 2019-02-26                  -0.006030           -0.006118
# 1015 2019-02-27                  -0.003739           -0.013566
# 1016 2019-02-28                   0.001146            0.017573
# 1017 2019-03-01                   0.005292            0.006227
# ...
